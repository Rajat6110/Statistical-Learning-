# %%
import numpy as np

# %%
#mean 
age = [ 28,56,24,65,25]


mean =  (28+56+24+65+25 )/5

# %%
mean
# Out:
# 39.6

# %%
#by lib

np.mean(age)
# Out:
# 39.6

# %%
heigt = [ 145,167,100,180,122]
np.mean(heigt)
# Out:
# 142.8

# %%
#median

# %%
n = [ 4,4,5,2,5]
np.median(n)
# Out:
# 4.0

# %%
#mode

# %%
np.mod(n)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 np.mod(n)
#
# TypeError: remainder() takes from 2 to 3 positional arguments but 1 were given

# %%
#numpy does'nt have numpy

# %%
from scipy import stats

# %%
stats.mode(n)
# Out:
# ModeResult(mode=4, count=2)

# %%
#another way

# %%
import statistics

# %%
statistics.mode(n)
# Out:
# 4

# %%
n = [ 1,2,3,4,5]
statistics.mode(n)
# Out:
# 1

# %%
statistics.median(n)
# Out:
# 3

# %%
# the mean is effected by  outliers

# %%
heigt
# Out:
# [145, 167, 100, 180, 122]

# %%
H = [145, 167, 100, 180, 122 ,1000]

# %%
np.mean(H)
# Out:
# 285.6666666666667

# %%
np.median(H)
# Out:
# 156.0

# %%
# mean is highly affected by outliers wheere as median does'nt have any effecct

# %%
np.median(H)
# Out:
# 156.0

# %%
arr = [ 1,2,3,4,5]
np.mean(arr)
# Out:
# 3.0

# %%
np.median(arr)
# Out:
# 3.0

# %%
arr = [ 1,2,3,4,5 ,6]

# %%
np.median(arr)
# Out:
# 3.5
