# %%
data = [ 1,2,3,4,5]
data
# Out:
# [1, 2, 3, 4, 5]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
np.mean(data)
# Out:
# 3.0

# %%
np.median(data)
# Out:
# 3.0

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# avg total mean

# %%
np.mean(df['total_bill'])
# Out:
# 19.78594262295082

# %%
np.median(df['total_bill'])
# Out:
# 17.795

# %%
#mean is affected by ouliers
data
# Out:
# [1, 2, 3, 4, 5]

# %%
data = [1, 2, 3, 4, 500]

# %%
np.mean(data)
# Out:
# 102.0

# %%
np.median(data) # meadian does'nt afftect by median
# Out:
# 3.0

# %%
data = [ 1,2,2,3,2,100,100,3]

# %%
import statistics

# %%
statistics.mode(data)
# Out:
# 2

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
np.percentile(data , [25,30,99])
# Out:
# array([  2.,   2., 100.])

# %%
np.percentile(data , 55)
# Out:
# 2.8500000000000005

# %%
data.append(-800)

# %%
data.append(600)

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %%
np.var(data)
# Out:
# 102001.41

# %%
np.std(data)
# Out:
# 319.37659588642373

# %%
statistics.variance(data) # sample varinace ( denomanator is n-1)
# Out:
# 113334.9

# %%
statistics.pvariance(data)
# Out:
# 102001.41

# %%
import math

# %%
math.sqrt(statistics.pvariance(data))
# Out:
# 319.37659588642373

# %%
corr = df.corr(numeric_only = True)

# %%
sns.heatmap(corr , annot = True)
# Out:
# <Axes: >

# %%
df.cov(numeric_only = True)
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
sns.pairplot(df)

# %%
sns.histplot(df['total_bill'] , kde = True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
d = np.random.normal(.5 , 1 , 1000)

# %%
sns.histplot(d , kde = True)
# Out:
# <Axes: ylabel='Count'>
